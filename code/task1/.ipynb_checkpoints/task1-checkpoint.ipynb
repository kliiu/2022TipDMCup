# %%
import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt
import re
import jieba
import jieba.analyse
import os

# %%
path="../dataset/2018-2019茂名（含自媒体）.xlsx"
df= pd.read_excel(path,sheet_name=4)
newdf=pd.read_excel(path,sheet_name=4)

# %%
newdf['正文']=(newdf['正文'].replace("\n",''))

# %%
content_len=[]
for i in range(621):
    row=newdf.loc[i,'正文']
    print(len(row))
    #print(row)
    row=row.replace("\n",'')
    row=row.replace(" ",'')
    content_len.append(len(row))
    print(len(row))
    #print(row)
    print('----------------------------')
# Out:
# 846
# 756
# ----------------------------
# 793
# 762
# ----------------------------
# 1402
# 1339
# ----------------------------
# 271
# 252
# ----------------------------
# 43
# 0
# ----------------------------
# 26172
# 25885
# ----------------------------
# 33
# 31
# ----------------------------
# 1069
# 1057
# ----------------------------
# 493
# 459
# ----------------------------
# 317
# 295
# ----------------------------
# 318
# 296
# ----------------------------
# 377
# 352
# ----------------------------
# 1876
# 1801
# ----------------------------
# 870
# 817
# ----------------------------
# 1601
# 1541
# ----------------------------
# 177
# 160
# ----------------------------
# 228
# 206
# ----------------------------
# 493
# 459
# ----------------------------
# 228
# 206
# ----------------------------
# 177
# 160
# ----------------------------
# 1602
# 1541
# ----------------------------
# 563
# 508
# ----------------------------
# 913
# 860
# ----------------------------
# ...

# %%
newdf['str_len']=content_len

# %%
newdf.describe()
# Out:
#               文章ID       str_len
# count   621.000000    621.000000
# mean   1311.000000   1416.267311
# std     179.411538   1616.056527
# min    1001.000000      0.000000
# 25%    1156.000000    583.000000
# 50%    1311.000000   1050.000000
# 75%    1466.000000   1806.000000
# max    1621.000000  25885.000000

# %%
#先将标题和正文合在一起，并删除其他列
#newdf["content"]=df["公众号标题"]+df["正文"]
#newdf.drop({"公众号标题","正文","发布时间"},axis=1,inplace=True)

# %%
#不分开标题和正文
newdf.drop({"发布时间"},axis=1,inplace=True)

# %%
#去除str中的空字符
strinfo = re.compile(' ')
#newdf["content"]=newdf["content"].apply(lambda x:strinfo.sub("",x))
newdf["公众号标题"]=newdf["公众号标题"].apply(lambda x:strinfo.sub("",x))

# %%
#去除str中的数字
for row in range(621):
    #print("---------------"+str(row)+"--------------------")
    newdf["content"][row] = ''.join([i for i in newdf["content"][row] if not i.isdigit()])
    #print(newdf["content"][row])
# Out:
# C:\Users\k\anaconda3\envs\pyto\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
newdf
# Out:
#      文章ID                                            content
# 0    1001  ，对自己好一点的旅程已经结束\n的未来拉开了帷幕\n新的一年里，请对自己好一点\n一辈子很长...
# 1    1002  春节机票预订有窍门距离春节还有一个多月的时间，在线旅游网站的春节机票销售火爆，部分航线甚至一...
# 2    1003  冬日旅游知多D万平方公里的祖国大地，四季都有独特美景\n冬天的旅行也别有一番风味\n但是冬季...
# 3    1004  冬季暖心之旅长按二维码，关注我们\n中心联系人：林小姐\n刘小姐\n罗小姐\n陈小姐\n市区...
# 4    1005                             关于粤K号大客车排气管“喷火”事件的情况说明
# ..    ...                                                ...
# 616  1617  北部湾城市运动会我市代表队喜获佳绩由北部湾经济合作组织、玉林市人民政府主办的第二届北部湾城市...
# 617  1618  茂名市交通建设投资集团有限公司新年文艺晚会现场直播，敬请关注！收看现场直播请点击文章最后面：...
# 618  1619  北部湾城市运动会，茂名代表队喜获佳绩！由北部湾经济合作组织、玉林市人民政府主办的第二届北部湾...
# 619  1620  睇年例、游滨海……这个冬天，就到茂名过大年！茂名，一座面朝大海、四季花开的好心之城。一座全年...
# 620  1621  茂名交投集团——徒步路上，不忘初心！茂名交投集团——鲲鹏展翅德行天下\n\n年月日（今天）\...
#
# [621 rows x 2 columns]

# %%
#特殊符号
special_words=["\t","\n","★","↓","▼","…","|","◆","!","☆","▶","▷","█","●","👇"]
# 创建停用词列表
def stopwordslist():
    stopwords = [line.strip() for line in open('stopwords/hit_stopwords.txt',encoding='utf-8').readlines()]
    return stopwords
# 对句子进行中文分词
def seg_depart(sentence):
    # 对文档中的每一行进行中文分词
    sentence_depart = jieba.cut(sentence.strip())
    # 创建一个停用词列表
    stopwords = stopwordslist()
    # 输出结果为outstr
    outstr = ''
    # 去停用词
    for word in sentence_depart:
        if word not in stopwords:
            if word not in special_words:
                outstr += word
                outstr += " "
    return outstr

# %%
#print(newdf["content"].iloc[0])

# %%
for row in range(621):
    print("---------------"+str(row)+"--------------------")
    newdf["content"][row]=seg_depart((newdf["content"].iloc[row]))
    print(newdf["content"][row])
# Out:
# ---------------0--------------------
# 好 一点 旅程 已经 结束 未来 拉开 帷幕 新 一年 里 请 好 一点 一辈子 很长 漫漫 人生 路上 会 遇到 人和事 一辈子 很 短 一年 一年 时光 悄悄 指缝间 溜走 有限 生命 里 现在 享受 人生 不 强求 缘分 遇见 人 总会 遇见 留不住 过客 终将 远走 有缘 相守 心怀 感恩 无缘 结交 坦然 放手 不 强求 都 自由 随缘 好 陪伴 家人 站 身后 家人 前进 时 坚强 后盾 给予 无条件 支持 孤独 无助 时 避风港 默默 付出 不求 回报 时间 留 一点 家人 需 陪伴 珍惜 朋友 时光流逝 仿佛 大浪淘沙 留下来 真心 朋友 不多不少 刚刚 好 三五 知己 小酌 几杯 君子之交 虽淡 贵在 真心 足矣 认真 工作 新 一年 里 全身心 投入 工作 付出 会 回报 工作 会为 搭 梦想 人生价值 之间 桥梁 认真 工作 辜负 爱护 身体 健康 体魄 最大 本钱 闲暇 时 散散步 锻炼 一下 身体 自律 健康 作息 身体 负责 出去 走走 心灵 需要 放松 远行 城市 里 拥挤 高楼 令人 迷茫 不妨 出去 走走 行万里路 感受 万里 风光 体验 形色 人生 过去 已经 过去 未来 即将 到来 新 一年 愿 想要 明天 都 终将 到来 更 精彩 线路 欢迎 关注 茂名 交投 旅游 集散中心 站 前 四路 交委 车站 一楼 中心 联系人 林小姐 刘小姐 罗 小姐 陈小姐 市区 联系人 柯 小姐 柯 先生 吴小姐 梁小姐 邓 先生 电白 分部 蔡 小姐 高州 分部 唐小姐 化州 分部 马先生 李小姐 信宜 分部 陈小姐 谢小姐
# ---------------1--------------------
# ...

# %%
"""
#构建文旅词典
#a="旅游、活动、节庆、特产、交通、酒店、景区、景点、文创、文化、乡村旅游、民宿、假日、假期、游客、采摘、赏花、春游、踏青、 康养、公园、滨海游、度假、农家乐、剧本杀、旅行、徒步、工业旅游、线路、自驾游、团队游、攻略、游记、包车、玻璃栈道、游艇、高尔夫、温泉"
#tripdic=a.split("、")
tripdic=['文化精神','背包旅行','市区包车','民族文化','度假之旅','长假','当地特产','悬崖栈道','游玩攻略','透露','住民宿','大假','以及交通','写一篇游记','庆典节日','交通方面','船','赏春','酒店房间','去郊游','著名的旅游景点','生态康养','徙步','房车旅行','线路建设','拼车包车','乡村旅游建设','公交线路','游客参观','家庭游','传统节日','嘉旅','自驾','特色景点','乡村生态旅游','重大节庆活动','体育公园','坐大巴','温泉养生','清楚','休闲度假','乡村旅游景点','旅行社团队','休闲农业','交通路线','温泉游','文创品牌','徒步','外国游客','滨海旅游','时令节庆','大众高尔夫','包车服务','主线路','度假休闲','踏春赏花','轮船','黄金假期','行记','张家界大峡谷','攻略','采摘时间','节日庆典','体验采摘','写攻略','奢华游艇','精品客栈','房车游','运动旅行','集体春游','主干线路','乡村旅游','最强攻略','悬空栈道','超级游艇','绿地公园','特色乡村','旅行','文化艺术','我的旅行','家庭日','豪华的游艇','历史文化','休闲农业与乡村旅游','国家级景区','海口旅游','创意体验','深度旅游','茶叶采摘','赏荷','以及文化','游记文章','包车游','温泉地','著名景点','全国工业旅游示范点','温泉景区','旅行见闻','采摘收获','果实采摘','包括旅游','家乡的特产','踏青','裸心谷','游记系列','文化创意产业','联系包车','乡村旅游开发','特产食品','搭车','摘果','泡温泉','重要节庆','自由行攻略','采下','杂记','海上旅游','农家乐饭店','旅游发展','度假村','重要景点','去度假','朗境','张家界大峡谷玻璃桥','游览景点','景点众多','城市旅游','特色旅游小镇','春天踏青','农业旅游','民宿发展','其它景点','踏春出游','养生养老产业','海边度假','各地游客','租车自驾游','当地酒店','文旅','旅行之后','民宿体验','游记攻略','去踏青','喜庆节日','游轮','包车司机','民俗节庆','莫干山民宿','观海长廊','旅店','旅游相关','去春游','名产','传统文化','短途游','农家旅馆','放假期间','滨河公园','温泉水','徒步探险','文化','人工采摘','历史景点','特色工业','热门景点','水上交通','外来游客','打造文化','踏春','线路','节庆日','元旦放假','雕塑公园','亲水游','自驾游爱好者','穿越原始森林','自然景点','旅行车','班级春游','度假酒店','郊游踏青','酒店中','度假旅游','阳光康养','度假旅行','温泉酒店','一家民宿','旅游社','高尔夫文化','节假日','温泉胜地','旅行经历','高隆湾','国内游','天门山玻璃栈道','文化融合','海上游','浪漫度假','文创旅游','海口湾','农家饭庄','铁路交通','和酒店','一起采摘','假期中','自驾出行','组团游','热汤','民宿管家','小周末','特色食品','台湾游客','游客体验','赏花踏青','线路长度','旅行日记','长假期','邮轮','森林康养','赏海棠','徒步旅行','租车','公共交通','高档酒店','机票酒店','旅游方面','吸引游客','特色农家','交通运输','体现','运输','房车自驾游','豪华邮轮','特产','温泉区','赏牡丹','奥迪','悠闲度假','欧洲旅行','农家乐发展','小快艇','文创园区','健康养生产业','跟团旅游','乡宿','长途自驾','温泉度假村','农家客栈','休息天','文创产业园','小游艇','包车费','民宿特色','景区外','滨水公园','包车价格','旅行日志','其他线路','高端民宿','旅游创新','张家界玻璃栈道','酒店大堂','核心景点','周边短途','假期时间','五一假期','租车包车','旅游车','环线','国内旅行社','浪漫海岸','去秋游','玻璃桥','出国旅行','国内自驾游','旅游区','尚酷','文化科技','游客多','到酒店','出现','难得的假期','旅馆','这个假期','骑行','玻璃栈桥','策略','栈道','度假养生','假期安排','搭客','乡村客栈','赏梨花','养生度假','交通设施','出产','夏威夷度假','关于旅行','养生温泉','旅行中','旅行度假','文化基因','新线路','著名景区','旅游养生','天然温泉','娱乐','吐露','采摘加工','农家乐餐馆','享受温泉','羽毛球','旅行生活','马尔代夫度假','负重徒步','温泉旅游','其他景点','春节自驾','新高尔夫','本土特产','民宿','自然景区','团体旅游','去旅行','旅客','春节假期','养生休闲','邮轮航线','乡村农家乐','张家界天门山玻璃栈道','景点','特色客栈','旅游生活','旅游景区','自驾车','假日酒店','旅行版','农家饭店','风景区','各地的特产','自由行','索桥','传统节庆','西游','土特产品','节假','旅游产业','其他景区','区域交通','酒店内','机场酒店','乡村休闲','各种节庆活动','高尔夫嘉旅','人文','小型游艇','必去景点','度假享受','海岛度假','重装徒步','栈房','精品民宿','国内旅游','及旅游','滨海景区','海滨旅游','线路连接','公路交通','中国游客','看游记','采摘过程','远足','精华游记','果园采摘','攻略指南','赏花观景','特色温泉','外部交通','在旅行的路上','旅行团','节日','观光旅游','各种文化','旅行吧','踏青赏春','包括交通','文化特质','观光游客','工业旅游景点','豪华私人游艇','乘客','海上巴士','文创产业','文化的内涵','当地包车','踏青春游','比如旅游','国际游客','假日','采摘茶叶','主要景点','交通道路','休闲观光农业','生态公园','帆船游艇','游人','康养中心','重要节日','创意旅游','景区旅游','环球旅行','广场公园','徒步游览','旅游度假','一段旅行','半自由行','游玩','农家乐餐饮','运动康养','赏叶','各线路','全攻略','攻略游记','五星酒店','康养产业','文化旅游产业','野炊','路线攻略','滑索','私家游艇','旅途','节日活动','游览的景点','踏青出游','养生养老','表现','户外温泉','线路设置','各种旅游','春秋游','大景点','一场旅行','观赏桃花','攻略贴','著名的景点','旅游点','独特的文化','周末假日','泄漏','攻略玩法','高尔夫球运动','采摘','海陵岛','湖公园','喜欢旅行','自驾旅行','游记分享','美丽乡村','旅行途中','行走','渡假','游客观光','养生产业','工业游','中外游客','秋游','春游','特色民宿','散步','徒步穿越','踏青郊游','旅行笔记','创意设计','旅社','交通出行','采摘季节','来赏','地方特产','特产品','文化和历史','摘采','文化和传统','休闲假期','康疗','景区入口','懂得','比高尔夫','大船','高山温泉','火山温泉','成都包车','生态养生','以农家乐','长途自驾游','周边自驾游','各景区','海滨度假','文创','捷恩斯','发展农家乐','养生旅游','交通网络','高级酒店','爬山','徒步路线','徒步穿行','农家游','休假','园林','住宿酒店','自驾游','一次春游','徒步游','超强攻略','乡村旅游项目','自由行产品','休闲公园','主要景区','创意文化','采摘水果','线路部分','速腾','观光者','及交通','工业旅游示范点','中国文化','登山赏花','文化产业','周边旅游','民间节庆','包车游玩','休闲山庄','温矿泉','邮轮母港','游客','放假','城区线路','节日庆祝','全域旅游发展','赏茶花','地热温泉','快艇','乡村休闲游','住宿','公共交通设施','观景赏花','医养','集体出游','公路旅行','徒步之旅','采摘葡萄','清明踏青','大白','名胜景点','大型农家乐','海岛游','温泉资源','康体养生','我们的旅行','揭发','旅游风景区','青海湖一日游','团队游客','游览','当地民宿','乡村民宿','小长假','酒店度假','度假生活','旅游日记','文创品','旅游文创','海岛旅游','农家宴','游历','写西','众创','张家界玻璃桥','土产品','其他特产','行程攻略','赏梅','生活文化','及文创','参团游','乐园','张家界天门山','生态农家乐','美食攻略','文化创意','市内交通','旅行社组团','文创类','景观公园','寒假','春天赏花','周边游','呈现','国外度假','攻略手册','去自驾','室内温泉','中心公园','森林温泉','观花','民宿酒店','旅行攻略','风景名胜','赏桃花','运营线路','旅行文章','高尔夫运动','氡温泉','采摘季','攻略分享','邮轮旅游','周末踏青','滨海度假','通行','外出度假','酒店里','报团','品质游','旅游经历','当地交通','登山','文创设计','田间采摘','本地特产','休闲养生','民俗活动','旅游景点','旅游目的地','文创艺术','游园赏花','公园里','大众运动','农旅结合','文化创业','采收','学问','旅游消费','休闲农业旅游','美宿','民宿主人','春游活动','沐日','游客来','风景点','主题民宿','赏樱','租车自驾','游船','攻略一','交通方式','温泉','采撷','生态养老','赏花游园','中央公园','名特产','文化公园','全域旅游','文雅','找人拼车','徒步跋涉','徒步去','乡村休闲旅游','散客游','春游踏青','包车旅游','海外度假','线路情况','日本游客','采摘果实','市政公园',' 康养','文化形态','包车拼车','出国度假','所有攻略','民宿设计','乡村游','知识','深度旅行','徒步行走','徒步爬山','艺术创意','滨江公园','完全攻略','特色旅游','花园','台湾文创','温泉泡','旅游业态','温泉泡汤','知道','十一假期','街心公园','完美攻略','现场采摘','旅游体验','在旅途中','民宿旅游','出境游','本地市民','植物园','温泉池','旅游休闲','采草莓','民族节日','赏樱花','滨海浴场','当地租车','线路图','高端运动','台湾民宿','五星级酒店','踏青游玩','主干线','丽江包车','西宁包车','休闲时光','踏青去','健康养老','出行旅游','公众假期','知名景点','人文景点','旅游产业融合','市民游客','康养度假','分明','景区','历史和文化','植物公园','年节','船的','冷泉','观赏樱花','特产美食','特色乡村旅游','绝壁栈道','基地采摘','旅行社','文化旅游产品','公交线','旅行社组织','游艇','发展乡村旅游','休息日','游客众多','户外游','省钱攻略','租摩托车','假期','游艇出海','节庆活动','文化节日','新年假期','踏青赏花','自驾出游','工业旅游','采摘品尝','旅游者','高空索道','知名特产','旅游观光','自由采摘','堵塞','攻略篇','经典景点','周末','游艇会','运动型车','乡村旅游产业','特产水果','家乡特产','大型公园','旅游多','旅游业','创意产品','浮现','高空栈道','大公园','走漏','映现','文化传统','公共假期','土特产','小吃特产','五星级的酒店','户外踏青','农家宾馆','运行线路','旅游','功略','春季踏青','农旅融合','双休日','新民宿','其他游客','度假胜地','酒店','成熟采摘','海滩度假','纪行','游记类','散记','阳江海陵岛','当地的特产','踏春郊游','双体帆船','徒步者','景区大门','湿地公园','风景名胜区','春游秋游','攻略介绍','假期里','房车自驾','室外温泉','各类节日','温泉里','春节自驾游','它的文化','年假','水果特产','打高尔夫','其它线路','写游记','露天温泉','酒店餐厅','各地旅游','漫步','当地旅行社','海外游客','附近交通','客店','大型游艇','出外踏青','豪华酒店','高尔夫球','乡村旅游发展','观花赏景','包车','出行交通','赏梅花','必游景点','大力发展乡村旅游','休闲游','国家工业','主要交通','当地土特产','红色旅游','流露','社区公园','健康旅游','土产','飞拉达','春日踏青','酒店住宿','网球','四星级酒店','祭祀庆典','康养旅游','地域文化','滨海休闲','大型节日','家庭度假','特产小吃','半自助游','各种节庆','玻璃天桥','各种特产','登山徒步','高空玻璃','旅途中','生态旅游','周边交通','开放公园','养生基地','旅舍','悬空玻璃栈道','级景区','重大节日','度假模式','玻璃廊桥','民俗节日','农家乐项目','景区内','海滨游','农家院','采下来','清晰','农家乐旅游','自由行旅游','老虎伍兹','郊外踏青','休假日','音乐玻璃栈道','自驾旅游','享受旅行','包车出游','节日假期','自驾游玩','旅行游记','酒店入住','途步','道路交通','独特文化','短假','采摘期','郊游','森林公园','上班日','元旦','玻璃观景台','假期结束','以及旅游','及文化','团体游','包辆','采摘后','温泉浴','外地游客','周末自驾游','小景点','节庆','盛大节日','城市交通','线路一','自驾行','农家餐馆','出门旅行','观光','玻璃平台','外出踏青','公园内','海边游','一次旅行','表露','主要特产','闪现','小艇','海洋旅游','公园中','团队游','景区景点','邮轮游','玩海','轻装徒步','西行记','文明','农家乐','拼车游','赏菊','旅游团','文化传承','主景区','游记','驾游','交通状况','特色农家乐','自然温泉','知名景区','特产丰富','公园入口','内部交通','团队旅游','玻璃吊桥','游记散文','民宿客栈','去徒步','度蜜月','乡村旅馆','日本游记','广场','一个人的旅行','公园','文创商品','旅游特色','野外徒步','自驾车游','乡村特色旅游','独自旅行','游客中心','创意产业','帆船','摩托艇','新增线路','散客团','城市公园','私人游艇','各种假期','国内游客','度假','赏花','农家乐餐厅','驴行','跟团游','宾馆','各种攻略','现代文化','国庆假期','表示','团游','交通信息','春假','户外徒步','开放式公园','旅游攻略','泉质','实用攻略','农家乐园','徒步走','学生春游','高空滑索','核心景区','国外游客','交通','主要线路','农家餐饮','徒步登山','高尔夫','渔船','客栈','相关攻略','酒店设施','洋家乐','豪华游轮','长周末','滨海度假区','展现','汽艇','人文文化','揭开','盘龙崖玻璃栈道','民宿经济','品海鲜','喜庆活动','旅行景点','消费旅游','所有线路','标志性景点','滨海旅游区','游客数量','旅游工业','独家攻略','游客进入','精品酒店','研学旅游','旅行随笔','长空栈道','工业旅游产品','鬼谷栈道','艺术文化','三天假期','线路开通','玻璃栈道','一条线路','线路规划','乡村旅游业','酒店民宿','郊游活动','养老养生','重大节庆','森林养生','硫磺温泉','採摘','详细攻略','相关线路','踏青活动','完整攻略','真切','步行','豪华游艇','城市旅行','赏景','滨海游','野游','周末假期','剧本杀','休闲农庄','星级酒店','文创产品','攻略秘籍','元旦假期','家居','遗产旅游','规划线路','特色食物','人文精神']
searched_words="'文化精神','背包旅行','市区包车','民族文化','度假之旅','长假','当地特产','悬崖栈道','游玩攻略','透露','住民宿','大假','以及交通','写一篇游记','庆典节日','交通方面','船','赏春','酒店房间','去郊游','著名的旅游景点','生态康养','徙步','房车旅行','线路建设','拼车包车','乡村旅游建设','公交线路','游客参观','家庭游','传统节日','嘉旅','自驾','特色景点','乡村生态旅游','重大节庆活动','体育公园','坐大巴','温泉养生','清楚','休闲度假','乡村旅游景点','旅行社团队','休闲农业','交通路线','温泉游','文创品牌','徒步','外国游客','滨海旅游','时令节庆','大众高尔夫','包车服务','主线路','度假休闲','踏春赏花','轮船','黄金假期','行记','张家界大峡谷','攻略','采摘时间','节日庆典','体验采摘','写攻略','奢华游艇','精品客栈','房车游','运动旅行','集体春游','主干线路','乡村旅游','最强攻略','悬空栈道','超级游艇','绿地公园','特色乡村','旅行','文化艺术','我的旅行','家庭日','豪华的游艇','历史文化','休闲农业与乡村旅游','国家级景区','海口旅游','创意体验','深度旅游','茶叶采摘','赏荷','以及文化','游记文章','包车游','温泉地','著名景点','全国工业旅游示范点','温泉景区','旅行见闻','采摘收获','果实采摘','包括旅游','家乡的特产','踏青','裸心谷','游记系列','文化创意产业','联系包车','乡村旅游开发','特产食品','搭车','摘果','泡温泉','重要节庆','自由行攻略','采下','杂记','海上旅游','农家乐饭店','旅游发展','度假村','重要景点','去度假','朗境','张家界大峡谷玻璃桥','游览景点','景点众多','城市旅游','特色旅游小镇','春天踏青','农业旅游','民宿发展','其它景点','踏春出游','养生养老产业','海边度假','各地游客','租车自驾游','当地酒店','文旅','旅行之后','民宿体验','游记攻略','去踏青','喜庆节日','游轮','包车司机','民俗节庆','莫干山民宿','观海长廊','旅店','旅游相关','去春游','名产','传统文化','短途游','农家旅馆','放假期间','滨河公园','温泉水','徒步探险','文化','人工采摘','历史景点','特色工业','热门景点','水上交通','外来游客','打造文化','踏春','线路','节庆日','元旦放假','雕塑公园','亲水游','自驾游爱好者','穿越原始森林','自然景点','旅行车','班级春游','度假酒店','郊游踏青','酒店中','度假旅游','阳光康养','度假旅行','温泉酒店','一家民宿','旅游社','高尔夫文化','节假日','温泉胜地','旅行经历','高隆湾','国内游','天门山玻璃栈道','文化融合','海上游','浪漫度假','文创旅游','海口湾','农家饭庄','铁路交通','和酒店','一起采摘','假期中','自驾出行','组团游','热汤','民宿管家','小周末','特色食品','台湾游客','游客体验','赏花踏青','线路长度','旅行日记','长假期','邮轮','森林康养','赏海棠','徒步旅行','租车','公共交通','高档酒店','机票酒店','旅游方面','吸引游客','特色农家','交通运输','体现','运输','房车自驾游','豪华邮轮','特产','温泉区','赏牡丹','奥迪','悠闲度假','欧洲旅行','农家乐发展','小快艇','文创园区','健康养生产业','跟团旅游','乡宿','长途自驾','温泉度假村','农家客栈','休息天','文创产业园','小游艇','包车费','民宿特色','景区外','滨水公园','包车价格','旅行日志','其他线路','高端民宿','旅游创新','张家界玻璃栈道','酒店大堂','核心景点','周边短途','假期时间','五一假期','租车包车','旅游车','环线','国内旅行社','浪漫海岸','去秋游','玻璃桥','出国旅行','国内自驾游','旅游区','尚酷','文化科技','游客多','到酒店','出现','难得的假期','旅馆','这个假期','骑行','玻璃栈桥','策略','栈道','度假养生','假期安排','搭客','乡村客栈','赏梨花','养生度假','交通设施','出产','夏威夷度假','关于旅行','养生温泉','旅行中','旅行度假','文化基因','新线路','著名景区','旅游养生','天然温泉','娱乐','吐露','采摘加工','农家乐餐馆','享受温泉','羽毛球','旅行生活','马尔代夫度假','负重徒步','温泉旅游','其他景点','春节自驾','新高尔夫','本土特产','民宿','自然景区','团体旅游','去旅行','旅客','春节假期','养生休闲','邮轮航线','乡村农家乐','张家界天门山玻璃栈道','景点','特色客栈','旅游生活','旅游景区','自驾车','假日酒店','旅行版','农家饭店','风景区','各地的特产','自由行','索桥','传统节庆','西游','土特产品','节假','旅游产业','其他景区','区域交通','酒店内','机场酒店','乡村休闲','各种节庆活动','高尔夫嘉旅','人文','小型游艇','必去景点','度假享受','海岛度假','重装徒步','栈房','精品民宿','国内旅游','及旅游','滨海景区','海滨旅游','线路连接','公路交通','中国游客','看游记','采摘过程','远足','精华游记','果园采摘','攻略指南','赏花观景','特色温泉','外部交通','在旅行的路上','旅行团','节日','观光旅游','各种文化','旅行吧','踏青赏春','包括交通','文化特质','观光游客','工业旅游景点','豪华私人游艇','乘客','海上巴士','文创产业','文化的内涵','当地包车','踏青春游','比如旅游','国际游客','假日','采摘茶叶','主要景点','交通道路','休闲观光农业','生态公园','帆船游艇','游人','康养中心','重要节日','创意旅游','景区旅游','环球旅行','广场公园','徒步游览','旅游度假','一段旅行','半自由行','游玩','农家乐餐饮','运动康养','赏叶','各线路','全攻略','攻略游记','五星酒店','康养产业','文化旅游产业','野炊','路线攻略','滑索','私家游艇','旅途','节日活动','游览的景点','踏青出游','养生养老','表现','户外温泉','线路设置','各种旅游','春秋游','大景点','一场旅行','观赏桃花','攻略贴','著名的景点','旅游点','独特的文化','周末假日','泄漏','攻略玩法','高尔夫球运动','采摘','海陵岛','湖公园','喜欢旅行','自驾旅行','游记分享','美丽乡村','旅行途中','行走','渡假','游客观光','养生产业','工业游','中外游客','秋游','春游','特色民宿','散步','徒步穿越','踏青郊游','旅行笔记','创意设计','旅社','交通出行','采摘季节','来赏','地方特产','特产品','文化和历史','摘采','文化和传统','休闲假期','康疗','景区入口','懂得','比高尔夫','大船','高山温泉','火山温泉','成都包车','生态养生','以农家乐','长途自驾游','周边自驾游','各景区','海滨度假','文创','捷恩斯','发展农家乐','养生旅游','交通网络','高级酒店','爬山','徒步路线','徒步穿行','农家游','休假','园林','住宿酒店','自驾游','一次春游','徒步游','超强攻略','乡村旅游项目','自由行产品','休闲公园','主要景区','创意文化','采摘水果','线路部分','速腾','观光者','及交通','工业旅游示范点','中国文化','登山赏花','文化产业','周边旅游','民间节庆','包车游玩','休闲山庄','温矿泉','邮轮母港','游客','放假','城区线路','节日庆祝','全域旅游发展','赏茶花','地热温泉','快艇','乡村休闲游','住宿','公共交通设施','观景赏花','医养','集体出游','公路旅行','徒步之旅','采摘葡萄','清明踏青','大白','名胜景点','大型农家乐','海岛游','温泉资源','康体养生','我们的旅行','揭发','旅游风景区','青海湖一日游','团队游客','游览','当地民宿','乡村民宿','小长假','酒店度假','度假生活','旅游日记','文创品','旅游文创','海岛旅游','农家宴','游历','写西','众创','张家界玻璃桥','土产品','其他特产','行程攻略','赏梅','生活文化','及文创','参团游','乐园','张家界天门山','生态农家乐','美食攻略','文化创意','市内交通','旅行社组团','文创类','景观公园','寒假','春天赏花','周边游','呈现','国外度假','攻略手册','去自驾','室内温泉','中心公园','森林温泉','观花','民宿酒店','旅行攻略','风景名胜','赏桃花','运营线路','旅行文章','高尔夫运动','氡温泉','采摘季','攻略分享','邮轮旅游','周末踏青','滨海度假','通行','外出度假','酒店里','报团','品质游','旅游经历','当地交通','登山','文创设计','田间采摘','本地特产','休闲养生','民俗活动','旅游景点','旅游目的地','文创艺术','游园赏花','公园里','大众运动','农旅结合','文化创业','采收','学问','旅游消费','休闲农业旅游','美宿','民宿主人','春游活动','沐日','游客来','风景点','主题民宿','赏樱','租车自驾','游船','攻略一','交通方式','温泉','采撷','生态养老','赏花游园','中央公园','名特产','文化公园','全域旅游','文雅','找人拼车','徒步跋涉','徒步去','乡村休闲旅游','散客游','春游踏青','包车旅游','海外度假','线路情况','日本游客','采摘果实','市政公园',' 康养','文化形态','包车拼车','出国度假','所有攻略','民宿设计','乡村游','知识','深度旅行','徒步行走','徒步爬山','艺术创意','滨江公园','完全攻略','特色旅游','花园','台湾文创','温泉泡','旅游业态','温泉泡汤','知道','十一假期','街心公园','完美攻略','现场采摘','旅游体验','在旅途中','民宿旅游','出境游','本地市民','植物园','温泉池','旅游休闲','采草莓','民族节日','赏樱花','滨海浴场','当地租车','线路图','高端运动','台湾民宿','五星级酒店','踏青游玩','主干线','丽江包车','西宁包车','休闲时光','踏青去','健康养老','出行旅游','公众假期','知名景点','人文景点','旅游产业融合','市民游客','康养度假','分明','景区','历史和文化','植物公园','年节','船的','冷泉','观赏樱花','特产美食','特色乡村旅游','绝壁栈道','基地采摘','旅行社','文化旅游产品','公交线','旅行社组织','游艇','发展乡村旅游','休息日','游客众多','户外游','省钱攻略','租摩托车','假期','游艇出海','节庆活动','文化节日','新年假期','踏青赏花','自驾出游','工业旅游','采摘品尝','旅游者','高空索道','知名特产','旅游观光','自由采摘','堵塞','攻略篇','经典景点','周末','游艇会','运动型车','乡村旅游产业','特产水果','家乡特产','大型公园','旅游多','旅游业','创意产品','浮现','高空栈道','大公园','走漏','映现','文化传统','公共假期','土特产','小吃特产','五星级的酒店','户外踏青','农家宾馆','运行线路','旅游','功略','春季踏青','农旅融合','双休日','新民宿','其他游客','度假胜地','酒店','成熟采摘','海滩度假','纪行','游记类','散记','阳江海陵岛','当地的特产','踏春郊游','双体帆船','徒步者','景区大门','湿地公园','风景名胜区','春游秋游','攻略介绍','假期里','房车自驾','室外温泉','各类节日','温泉里','春节自驾游','它的文化','年假','水果特产','打高尔夫','其它线路','写游记','露天温泉','酒店餐厅','各地旅游','漫步','当地旅行社','海外游客','附近交通','客店','大型游艇','出外踏青','豪华酒店','高尔夫球','乡村旅游发展','观花赏景','包车','出行交通','赏梅花','必游景点','大力发展乡村旅游','休闲游','国家工业','主要交通','当地土特产','红色旅游','流露','社区公园','健康旅游','土产','飞拉达','春日踏青','酒店住宿','网球','四星级酒店','祭祀庆典','康养旅游','地域文化','滨海休闲','大型节日','家庭度假','特产小吃','半自助游','各种节庆','玻璃天桥','各种特产','登山徒步','高空玻璃','旅途中','生态旅游','周边交通','开放公园','养生基地','旅舍','悬空玻璃栈道','级景区','重大节日','度假模式','玻璃廊桥','民俗节日','农家乐项目','景区内','海滨游','农家院','采下来','清晰','农家乐旅游','自由行旅游','老虎伍兹','郊外踏青','休假日','音乐玻璃栈道','自驾旅游','享受旅行','包车出游','节日假期','自驾游玩','旅行游记','酒店入住','途步','道路交通','独特文化','短假','采摘期','郊游','森林公园','上班日','元旦','玻璃观景台','假期结束','以及旅游','及文化','团体游','包辆','采摘后','温泉浴','外地游客','周末自驾游','小景点','节庆','盛大节日','城市交通','线路一','自驾行','农家餐馆','出门旅行','观光','玻璃平台','外出踏青','公园内','海边游','一次旅行','表露','主要特产','闪现','小艇','海洋旅游','公园中','团队游','景区景点','邮轮游','玩海','轻装徒步','西行记','文明','农家乐','拼车游','赏菊','旅游团','文化传承','主景区','游记','驾游','交通状况','特色农家乐','自然温泉','知名景区','特产丰富','公园入口','内部交通','团队旅游','玻璃吊桥','游记散文','民宿客栈','去徒步','度蜜月','乡村旅馆','日本游记','广场','一个人的旅行','公园','文创商品','旅游特色','野外徒步','自驾车游','乡村特色旅游','独自旅行','游客中心','创意产业','帆船','摩托艇','新增线路','散客团','城市公园','私人游艇','各种假期','国内游客','度假','赏花','农家乐餐厅','驴行','跟团游','宾馆','各种攻略','现代文化','国庆假期','表示','团游','交通信息','春假','户外徒步','开放式公园','旅游攻略','泉质','实用攻略','农家乐园','徒步走','学生春游','高空滑索','核心景区','国外游客','交通','主要线路','农家餐饮','徒步登山','高尔夫','渔船','客栈','相关攻略','酒店设施','洋家乐','豪华游轮','长周末','滨海度假区','展现','汽艇','人文文化','揭开','盘龙崖玻璃栈道','民宿经济','品海鲜','喜庆活动','旅行景点','消费旅游','所有线路','标志性景点','滨海旅游区','游客数量','旅游工业','独家攻略','游客进入','精品酒店','研学旅游','旅行随笔','长空栈道','工业旅游产品','鬼谷栈道','艺术文化','三天假期','线路开通','玻璃栈道','一条线路','线路规划','乡村旅游业','酒店民宿','郊游活动','养老养生','重大节庆','森林养生','硫磺温泉','採摘','详细攻略','相关线路','踏青活动','完整攻略','真切','步行','豪华游艇','城市旅行','赏景','滨海游','野游','周末假期','剧本杀','休闲农庄','星级酒店','文创产品','攻略秘籍','元旦假期','家居','遗产旅游','规划线路','特色食物','人文精神',"
searched_words=seg_depart(searched_words)
#转换为dic
tripdic=searched_words.split(" ")
tripdic=set(tripdic)
tripdic
temp=str(tripdic)
#将词典写入文件并人工去除无关词
with open('tempdic.txt','w')as file_obj:
    for i in tripdic:
        file_obj.write(i)
        file_obj.write('\n')
    file_obj.close()

"""
# Out:
# '\n#构建文旅词典\n#a="旅游、活动、节庆、特产、交通、酒店、景区、景点、文创、文化、乡村旅游、民宿、假日、假期、游客、采摘、赏花、春游、踏青、 康养、公园、滨海游、度假、农家乐、剧本杀、旅行、徒步、工业旅游、线路、自驾游、团队游、攻略、游记、包车、玻璃栈道、游艇、高尔夫、温泉"\n#tripdic=a.split("、")\ntripdic=[\'文化精神\',\'背包旅行\',\'市区包车\',\'民族文化\',\'度假之旅\',\'长假\',\'当地特产\',\'悬崖栈道\',\'游玩攻略\',\'透露\',\'住民宿\',\'大假\',\'以及交通\',\'写一篇游记\',\'庆典节日\',\'交通方面\',\'船\',\'赏春\',\'酒店房间\',\'去郊游\',\'著名的旅游景点\',\'生态康养\',\'徙步\',\'房车旅行\',\'线路建设\',\'拼车包车\',\'乡村旅游建设\',\'公交线路\',\'游客参观\',\'家庭游\',\'传统节日\',\'嘉旅\',\'自驾\',\'特色景点\',\'乡村生态旅游\',\'重大节庆活动\',\'体育公园\',\'坐大巴\',\'温泉养生\',\'清楚\',\'休闲度假\',\'乡村旅游景点\',\'旅行社团队\',\'休闲农业\',\'交通路线\',\'温泉游\',\'文创品牌\',\'徒步\',\'外国游客\',\'滨海旅游\',\'时令节庆\',\'大众高尔夫\',\'包车服务\',\'主线路\',\'度假休闲\',\'踏春赏花\',\'轮船\',\'黄金假期\',\'行记\',\'张家界大峡谷\',\'攻略\',\'采摘时间\',\'节日庆典\',\'体验采摘\',\'写攻略\',\'奢华游艇\',\'精品客栈\',\'房车游\',\'运动旅行\',\'集体春游\',\'主干线路\',\'乡村旅游\',\'最强攻略\',\'悬空栈道\',\'超级游艇\',\'绿地公园\',\'特色乡村\',\'旅行\',\'文化艺术\',\'我的旅行\',\'家庭日\',\'豪华的游艇\',\'历史文化\',\'休闲农业与乡村旅游\',\'国家级景区\',\'海口旅游\',\'创意体验\',\'深度旅游\',\'茶叶采摘\',\'赏荷\',\'以及文化\',\'游记文章\',\'包车游\',\'
# ...

# %%
#再将词典读出
new_dic=[]
with open('tempdic.txt','r')as file_obj:
    for line in file_obj.readlines():
        new_dic.append(line[:-1])#不读最后的换行符

# %%
len(new_dic)
# Out:
# 517

# %%
#去除重复
lst = []
for el in new_dic:
    if lst.count(el) < 1:
        lst.append(el)
    else:
        print(el)
  # 没有问题,也能保留原有顺序,但是创建了新列表

# %%
len(lst)
# Out:
# 517

# %%
#保存每篇文章各包含词表的单词个数列表
#相关的
relevent=[]
#不相关的
#将相关和不相关的分开
irrelevent=[i for i in range(621)]

dic_cnt=[]
ori_len=[]
for row in range(621):
    d_cnt=0#计数
    o_cnt=0
    for word in newdf["content"][row].split(" "):
        o_cnt+=1
        if word in new_dic:
            #irrelevent.remove(row)
            #relevent.append(row)
            d_cnt+=1
    dic_cnt.append(d_cnt)
    ori_len.append(o_cnt)

# %%
analysis_words=newdf.copy()
analysis_words["ori_word_len"]=ori_len#原始词数
analysis_words["dic_word_cnt"]=dic_cnt#出现词表中的词的次数
analysis_words["frequency"]=analysis_words["dic_word_cnt"]/analysis_words["ori_word_len"]
analysis_words
# Out:
#      文章ID                                            content  ori_word_len  \
# 0    1001  好 一点 旅程 已经 结束 未来 拉开 帷幕 新 一年 里 请 好 一点 一辈子 很长 漫漫...           230
# 1    1002  春节 机票 预订 窍门 距离 春节 一个多月 时间 在线 旅游 网站 春节 机票 销售 火爆...           239
# 2    1003  冬日 旅游 知多 D 万平方公里 祖国 大地 四季 都 独特 美景 冬天 旅行 风味 冬季 ...           447
# 3    1004  冬季 暖心 旅长 二维码 关注 中心 联系人 林小姐 刘小姐 罗 小姐 陈小姐 市区 联系人...            38
# 4    1005                         粤 K 号 大客车 排气管 喷火 事件 情况 说明             10
# ..    ...                                                ...           ...
# 616  1617  北部湾 城市 运动会 我市 代表队 喜获 佳绩 北部湾 经济合作组织 玉林市 人民政府 主办...            92
# 617  1618  茂名市 交通 建设 投资 集团 有限公司 新年 文艺晚会 现场直播 敬请 关注 收看 现场直...           183
# 618  1619  北部湾 城市 运动会 茂名 代表队 喜获 佳绩 北部湾 经济合作组织 玉林市 人民政府 主办...           197
# 619  1620  睇 年例 游 滨海 冬天 茂名 过大年 茂名 一座 面朝 大海 四季 花开 好心 城 一座 ...          1477
# 620  1621  茂名 交投 集团 徒步 路上 不忘 初心 茂名 交投 集团 鲲鹏展翅 德行 天下 年月日 今...           456
#
#      dic_word_cnt  frequency
# 0               7   0.030435
# ...

# %%
"""标准化
temp_df=analysis_words
temp_df['nor_len']=(temp_df['ori_word_len']-temp_df['ori_word_len'].mean())/(temp_df['ori_word_len'].max()-temp_df['ori_word_len'].min())
temp_df['nor_cnt']=(temp_df['dic_word_cnt']-temp_df['dic_word_cnt'].mean())/(temp_df['dic_word_cnt'].max()-temp_df['dic_word_cnt'].min())
temp_df['nor_fre']=(temp_df['frequency']-temp_df['frequency'].mean())/(temp_df['frequency'].max()-temp_df['frequency'].min())
temp_df
"""
# Out:
# "标准化\ntemp_df=analysis_words\ntemp_df['nor_len']=(temp_df['ori_word_len']-temp_df['ori_word_len'].mean())/(temp_df['ori_word_len'].max()-temp_df['ori_word_len'].min())\ntemp_df['nor_cnt']=(temp_df['dic_word_cnt']-temp_df['dic_word_cnt'].mean())/(temp_df['dic_word_cnt'].max()-temp_df['dic_word_cnt'].min())\ntemp_df['nor_fre']=(temp_df['frequency']-temp_df['frequency'].mean())/(temp_df['frequency'].max()-temp_df['frequency'].min())\ntemp_df\n"

# %%
analysis_words.describe()
# Out:
#               文章ID  ori_word_len  dic_word_cnt   frequency
# count   621.000000    621.000000    621.000000  621.000000
# mean   1311.000000    531.653784     66.816425    0.115555
# std     179.411538    593.778804     91.625228    0.060431
# min    1001.000000      5.000000      0.000000    0.000000
# 25%    1156.000000    229.000000     18.000000    0.072539
# 50%    1311.000000    403.000000     45.000000    0.113721
# 75%    1466.000000    680.000000     92.000000    0.153846
# max    1621.000000   9678.000000   1626.000000    0.322124

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# 解决保存图像是负号'-'显示为方块的问题
plt.rcParams['axes.unicode_minus'] = False  
# style设置
sns.set_style('whitegrid', {'font.sans-serif': ['simhei','FangSong']})
ax = sns.boxplot(x=analysis_words["frequency"])
ax.set_title('词典词语出现频率')
box_fig=ax.get_figure()
fig_path='fig/box'
box_fig.savefig(fig_path, dpi = 400)

# %%
break_point=0.072539#分割点

# %%
relevent_data=(analysis_words[analysis_words['frequency']>break_point])['文章ID']
irrelevent_data=analysis_words[analysis_words['frequency']<=break_point]
irrelevent_data.to_excel('irrelevent.xlsx',index=False)
relevent_data.to_excel('relevent.xlsx',index=False)

# %%
relevent_ID=(analysis_words[analysis_words['frequency']>break_point])['文章ID']
irrelevent_ID=(analysis_words[analysis_words['frequency']<=break_point])['文章ID']

# %%
(analysis_words[analysis_words['文章ID']==1005])['content']
# Out:
# 4    粤 K 号 大客车 排气管 喷火 事件 情况 说明
# Name: content, dtype: object

# %%
relevent_ID
# Out:
# 1      1002
# 2      1003
# 5      1006
# 8      1009
# 11     1012
#        ...
# 614    1615
# 615    1616
# 618    1619
# 619    1620
# 620    1621
# Name: 文章ID, Length: 465, dtype: int64

# %%
irrelevent_ID
# Out:
# 0      1001
# 3      1004
# 4      1005
# 6      1007
# 7      1008
#        ...
# 585    1586
# 591    1592
# 610    1611
# 616    1617
# 617    1618
# Name: 文章ID, Length: 156, dtype: int64

# %%
ori_irrelevent_data=df.drop(i for i in (relevent_ID-1001) )
ori_irrelevent_data.to_excel('ori_irrelevent.xlsx',index=False)
ori_relevent_data=df.drop(i for i in (irrelevent_ID-1001) )
ori_relevent_data.to_excel('ori_relevent.xlsx',index=False)
